# %%
import pandas as pd

# %%
stats = pd.read_csv('../cbb/cbb25.csv')
stats = stats.drop(columns=['POSTSEASON', 'CONF', 'Unnamed: 24'])
stats
# Out:
#                 TEAM   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD  \
# 0        Alabama St.  34  19  100.5  109.6   0.2698   47.1   50.3  13.2  18.6
# 1    Saint Francis U  33  16   99.9  112.0   0.2114   51.6   51.3  19.6  16.4
# 2   Mount St. Mary's  34  22   99.4  107.5   0.2903   51.0   48.0  21.7  15.9
# 3             Xavier  32  21  116.3   97.8   0.8797   53.9   50.6  16.0  17.6
# 4              Texas  34  19  116.7  100.2   0.8524   52.5   48.4  14.3  16.6
# ..               ...  ..  ..    ...    ...      ...    ...    ...   ...   ...
# 63           Wofford  34  19  111.4  109.8   0.5422   53.3   51.8  16.9  14.9
# 64     Robert Morris  34  26  106.0  105.1   0.5265   51.3   50.3  18.5  18.8
# 65            Bryant  34  23  105.9  105.4   0.5122   51.0   47.7  16.5  16.4
# 66       Norfolk St.  34  24  106.4  109.1   0.4276   52.4   49.7  18.3  18.6
# 67  SIU Edwardsville  33  22  101.5  105.8   0.3822   48.9   47.5  17.1  17.3
#
# ...

# %%
matchups = pd.read_csv('../mm/mm/mm25.csv')
matchups
# Out:
#     winner  SEED_higher  SEED_lower      TEAM_higher  G_higher  W_higher  \
# 0      NaN          NaN         NaN           Auburn       NaN       NaN
# 1      NaN          NaN         NaN       Louisville       NaN       NaN
# 2      NaN          NaN         NaN         Michigan       NaN       NaN
# 3      NaN          NaN         NaN        Texas A&M       NaN       NaN
# 4      NaN          NaN         NaN      Mississippi       NaN       NaN
# 5      NaN          NaN         NaN         Iowa St.       NaN       NaN
# 6      NaN          NaN         NaN        Marquette       NaN       NaN
# 7      NaN          NaN         NaN     Michigan St.       NaN       NaN
# 8      NaN          NaN         NaN          Florida       NaN       NaN
# 9      NaN          NaN         NaN      Connecticut       NaN       NaN
# 10     NaN          NaN         NaN          Memphis       NaN       NaN
# 11     NaN          NaN         NaN         Maryland       NaN       NaN
# ...

# %%
# row[4:25]
# teamHigh.iloc[:, 1:]
matchups = pd.read_csv('../mm/mm/mm25.csv')
for index, row in matchups.iterrows():
    teamHigh = stats.loc[stats['TEAM'] == row['TEAM_higher']]
    teamLow = stats.loc[stats['TEAM'] == row['TEAM_lower']]

    matchups['SEED_higher'].iloc[index] = teamHigh['SEED']
    matchups['G_higher'].iloc[index] = teamHigh['G']
    matchups['W_higher'].iloc[index] = teamHigh['W']
    matchups['ADJOE_higher'].iloc[index] = teamHigh['ADJOE']
    matchups['ADJDE_higher'].iloc[index] = teamHigh['ADJDE']
    matchups['BARTHAG_higher'].iloc[index] = teamHigh['BARTHAG']
    matchups['EFG_O_higher'].iloc[index] = teamHigh['EFG_O']
    matchups['EFG_D_higher'].iloc[index] = teamHigh['EFG_D']
    matchups['TOR_higher'].iloc[index] = teamHigh['TOR']
    matchups['TORD_higher'].iloc[index] = teamHigh['TORD']
    matchups['ORB_higher'].iloc[index] = teamHigh['ORB']
    matchups['DRB_higher'].iloc[index] = teamHigh['DRB']
    matchups['FTR_higher'].iloc[index] = teamHigh['FTR']
    matchups['FTRD_higher'].iloc[index] = teamHigh['FTRD']
    matchups['2P_O_higher'].iloc[index] = teamHigh['2P_O']
    matchups['2P_D_higher'].iloc[index] = teamHigh['2P_D']
    matchups['3P_O_higher'].iloc[index] = teamHigh['3P_O']
    matchups['3P_D_higher'].iloc[index] = teamHigh['3P_D']
    matchups['ADJ_T_higher'].iloc[index] = teamHigh['ADJ_T']
    matchups['WAB_higher'].iloc[index] = teamHigh['WAB']
    matchups['Turnover_diff_higher'].iloc[index] = teamHigh['TO_DIFF']


    matchups['SEED_lower'].iloc[index] = teamLow['SEED']
    matchups['G_lower'].iloc[index] = teamLow['G']
    matchups['W_lower'].iloc[index] = teamLow['W']
    matchups['ADJOE_lower'].iloc[index] = teamLow['ADJOE']
    matchups['ADJDE_lower'].iloc[index] = teamLow['ADJDE']
    matchups['BARTHAG_lower'].iloc[index] = teamLow['BARTHAG']
    matchups['EFG_O_lower'].iloc[index] = teamLow['EFG_O']
    matchups['EFG_D_lower'].iloc[index] = teamLow['EFG_D']
    matchups['TOR_lower'].iloc[index] = teamLow['TOR']
    matchups['TORD_lower'].iloc[index] = teamLow['TORD']
    matchups['ORB_lower'].iloc[index] = teamLow['ORB']
    matchups['DRB_lower'].iloc[index] = teamLow['DRB']
    matchups['FTR_lower'].iloc[index] = teamLow['FTR']
    matchups['FTRD_lower'].iloc[index] = teamLow['FTRD']
    matchups['2P_O_lower'].iloc[index] = teamLow['2P_O']
    matchups['2P_D_lower'].iloc[index] = teamLow['2P_D']
    matchups['3P_O_lower'].iloc[index] = teamLow['3P_O']
    matchups['3P_D_lower'].iloc[index] = teamLow['3P_D']
    matchups['ADJ_T_lower'].iloc[index] = teamLow['ADJ_T']
    matchups['WAB_lower'].iloc[index] = teamLow['WAB']
    matchups['Turnover_diff_lower'].iloc[index] = teamLow['TO_DIFF']
# Out:
# C:\Users\prest\AppData\Local\Temp\ipykernel_1300\450625310.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   matchups['SEED_higher'].iloc[index] = teamHigh['SEED']
# ...

# %%
matchups.to_csv('matchups25.csv', index=False)
